# %%
import morph_kgc
g = morph_kgc.materialize('config.ini')

g.serialize(destination='resultado.nt', format='nt')
print("Archivo resultado.nt generado ✅")
# Out:
# INFO | 2025-10-27 13:45:03,015 | Parallelization is not supported for win32 when running as a library. If you need to speed up your data integration pipeline, please run through the command line.
# INFO | 2025-10-27 13:45:04,540 | 19 mapping rules retrieved.
# INFO | 2025-10-27 13:45:04,565 | Mapping partition with 18 groups generated.
# INFO | 2025-10-27 13:45:04,569 | Maximum number of rules within mapping group: 2.
# INFO | 2025-10-27 13:45:04,570 | Mappings processed in 1.551 seconds.
# INFO | 2025-10-27 13:45:04,823 | Number of triples generated in total: 1082.
# Archivo resultado.nt generado ✅
# c:\Users\SergioBeamonteGonzal\AppData\Local\Programs\Python\Python313\Lib\site-packages\rdflib\plugins\serializers\nt.py:41: UserWarning: NTSerializer always uses UTF-8 encoding. Given encoding was: None
#   warnings.warn(
